# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv("data.csv")

# %%
df.shape
# Out:
# (7691, 10)

# %%
df.head()
# Out:
#                                           house_type       locality    city  \
# 0  2 BHK Flat for Rent in Oberoi Woods, Goregaon ...  Goregaon East  Mumbai
# 1  1 BHK Flat for Rent in Sapphire Lakeside, Powa...          Powai  Mumbai
# 2               1 BHK House for Rent in Mundhwa Pune        Mundhwa    Pune
# 3              2 BHK Flat for Rent in Hingna, Nagpur         Hingna  Nagpur
# 4  1 BHK Flat for Rent in Unique Star Harsh Vihar...      Mira Road  Mumbai
#
#      area  beds  bathrooms  balconies      furnishing  area_rate      rent
# 0   897.0     2          2          0  Semi-Furnished      134.0  120000.0
# 1   490.0     1          1          0  Semi-Furnished       82.0   40000.0
# 2   550.0     1          1          0     Unfurnished       22.0   12000.0
# 3  1000.0     2          2          0     Unfurnished        8.0    8000.0
# 4   595.0     1          1          0     Unfurnished       25.0   15000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7691 entries, 0 to 7690
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   house_type  7691 non-null   object
#  1   locality    7691 non-null   object
#  2   city        7691 non-null   object
#  3   area        7691 non-null   float64
#  4   beds        7691 non-null   int64
#  5   bathrooms   7691 non-null   int64
#  6   balconies   7691 non-null   int64
#  7   furnishing  7691 non-null   object
#  8   area_rate   7691 non-null   float64
#  9   rent        7691 non-null   float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 601.0+ KB

# %%
for i in range(df.shape[0]):
    if df['house_type'][i][0]=='>':
        df['BHK'][i]=10
    else:
        df['BHK'][i]=df['house_type'][i][0]

# %%
df.head()
# Out:
#                                           house_type       locality    city  \
# 0  2 BHK Flat for Rent in Oberoi Woods, Goregaon ...  Goregaon East  Mumbai
# 1  1 BHK Flat for Rent in Sapphire Lakeside, Powa...          Powai  Mumbai
# 2               1 BHK House for Rent in Mundhwa Pune        Mundhwa    Pune
# 3              2 BHK Flat for Rent in Hingna, Nagpur         Hingna  Nagpur
# 4  1 BHK Flat for Rent in Unique Star Harsh Vihar...      Mira Road  Mumbai
#
#      area  beds  bathrooms  balconies      furnishing  area_rate      rent BHK
# 0   897.0     2          2          0  Semi-Furnished      134.0  120000.0   2
# 1   490.0     1          1          0  Semi-Furnished       82.0   40000.0   1
# 2   550.0     1          1          0     Unfurnished       22.0   12000.0   1
# 3  1000.0     2          2          0     Unfurnished        8.0    8000.0   2
# 4   595.0     1          1          0     Unfurnished       25.0   15000.0   1

# %%
df['BHK'].unique()
# Out:
# array(['2', '1', '3', '4', '5', 10, '8', '7', '6'], dtype=object)

# %%
type(df['BHK'][0])
# Out:
# numpy.int64

# %%
df['BHK']=df['BHK'].astype(int)

# %%
df.drop('house_type',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['locality', 'city', 'area', 'beds', 'bathrooms', 'balconies',
#        'furnishing', 'area_rate', 'rent', 'BHK'],
#       dtype='object')

# %%
df.head()
# Out:
#         locality    city    area  beds  bathrooms  balconies      furnishing  \
# 0  Goregaon East  Mumbai   897.0     2          2          0  Semi-Furnished
# 1          Powai  Mumbai   490.0     1          1          0  Semi-Furnished
# 2        Mundhwa    Pune   550.0     1          1          0     Unfurnished
# 3         Hingna  Nagpur  1000.0     2          2          0     Unfurnished
# 4      Mira Road  Mumbai   595.0     1          1          0     Unfurnished
#
#    area_rate      rent  BHK
# 0      134.0  120000.0    2
# 1       82.0   40000.0    1
# 2       22.0   12000.0    1
# 3        8.0    8000.0    2
# 4       25.0   15000.0    1

# %%
df.drop('locality',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['city', 'area', 'beds', 'bathrooms', 'balconies', 'furnishing',
#        'area_rate', 'rent', 'BHK'],
#       dtype='object')

# %%
df.head()
# Out:
#      city    area  beds  bathrooms  balconies      furnishing  area_rate  \
# 0  Mumbai   897.0     2          2          0  Semi-Furnished      134.0
# 1  Mumbai   490.0     1          1          0  Semi-Furnished       82.0
# 2    Pune   550.0     1          1          0     Unfurnished       22.0
# 3  Nagpur  1000.0     2          2          0     Unfurnished        8.0
# 4  Mumbai   595.0     1          1          0     Unfurnished       25.0
#
#        rent  BHK
# 0  120000.0    2
# 1   40000.0    1
# 2   12000.0    1
# 3    8000.0    2
# 4   15000.0    1

# %%
df['city'].unique()
# Out:
# array(['Mumbai', 'Pune', 'Nagpur', 'Bangalore', 'New Delhi'], dtype=object)

# %%
df['city']=df['city'].map({'Mumbai':0,'Pune':1,'New Delhi':2,'Bangalore':3,'Nagpur':4})

# %%
df.head()
# Out:
#    city    area  beds  bathrooms  balconies      furnishing  area_rate  \
# 0     0   897.0     2          2          0  Semi-Furnished      134.0
# 1     0   490.0     1          1          0  Semi-Furnished       82.0
# 2     1   550.0     1          1          0     Unfurnished       22.0
# 3     4  1000.0     2          2          0     Unfurnished        8.0
# 4     0   595.0     1          1          0     Unfurnished       25.0
#
#        rent  BHK
# 0  120000.0    2
# 1   40000.0    1
# 2   12000.0    1
# 3    8000.0    2
# 4   15000.0    1

# %%
df['furnishing'].unique()
# Out:
# array(['Semi-Furnished', 'Unfurnished', 'Furnished'], dtype=object)

# %%
df['furnishing']=df['furnishing'].map({'Semi-Furnished':1,'Furnished':2,'Unfurnished':0})

# %%
df.head()
# Out:
#    city    area  beds  bathrooms  balconies  furnishing  area_rate      rent  \
# 0     0   897.0     2          2          0           1      134.0  120000.0
# 1     0   490.0     1          1          0           1       82.0   40000.0
# 2     1   550.0     1          1          0           0       22.0   12000.0
# 3     4  1000.0     2          2          0           0        8.0    8000.0
# 4     0   595.0     1          1          0           0       25.0   15000.0
#
#    BHK
# 0    2
# 1    1
# 2    1
# 3    2
# 4    1

# %%
sns.pairplot(df,kind='reg')
plt.plot()
# Out:
# []

# %%
sns.boxplot(X)
plt.plot()
# Out:
# []

# %%
df1=df.drop('rent',axis=1)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X=scaler.fit_transform(df1)

# %%
df1.head()
# Out:
#    city    area  beds  bathrooms  balconies  furnishing  area_rate  BHK
# 0     0   897.0     2          2          0           1      134.0    2
# 1     0   490.0     1          1          0           1       82.0    1
# 2     1   550.0     1          1          0           0       22.0    1
# 3     4  1000.0     2          2          0           0        8.0    2
# 4     0   595.0     1          1          0           0       25.0    1

# %%
X
# Out:
# array([[-1.35845839, -0.17484809, -0.21006855, ...,  0.18856148,
#          1.2521533 , -0.20935375],
#        [-1.35845839, -0.51476569, -1.21669608, ...,  0.18856148,
#          0.49836813, -1.22393451],
#        [-0.5636388 , -0.46465499, -1.21669608, ..., -1.17828712,
#         -0.37138399, -1.22393451],
#        ...,
#        [-0.5636388 , -0.31098216, -0.21006855, ..., -1.17828712,
#          0.00550859, -0.20935375],
#        [ 0.23118078, -0.58993174, -1.21669608, ...,  0.18856148,
#         -0.13945009, -1.22393451],
#        [ 1.02600037, -0.54817282, -0.21006855, ..., -1.17828712,
#         -0.37138399, -0.20935375]], shape=(7691, 8))

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
x_train,x_test,y_train,y_test=train_test_split(df1,df['rent'],test_size=0.2,random_state=42)

# %%
model=RandomForestRegressor()

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred=model.predict(x_test)

# %%
error=mean_squared_error(y_test,y_pred)

# %%
error
# Out:
# 515440773.9144193

# %%
y_test.mean()
# Out:
# np.float64(53723.19818063678)

# %%
y_test.std()
# Out:
# np.float64(86596.69184627943)

# %%
y_test.max() - y_test.min()
# Out:
# np.float64(1199000.0)

# %%
Residuals = y_test - y_pred

# %%
plt.scatter(y_pred, Residuals)

# %%
cross_val_score(model, X, y, cv=5, scoring='neg_mean_squared_error')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 cross_val_score(model, X, y, cv=5, scoring='neg_mean_squared_error')
#
# NameError: name 'cross_val_score' is not defined
